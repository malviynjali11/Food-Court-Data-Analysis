# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Datasets/Item-wise sales.xlsx')
data.head()
# Out:
#            Item Name   Category  Total Quantity(Oct-Dec23)  \
# 0  V. Paneer Prantha      Meals                        0.0
# 1      Special Thali      Meals                     2777.0
# 2       Water Bottle  Beverages                     3309.0
# 3    V. Poori Cholle      Meals                        0.0
# 4     Veg Fried Rice      Meals                      178.0
#
#    Total Amount (Oct-Dec23)  Total Quantity(Jan-Mar24)  \
# 0                      0.00                      703.0
# 1                 264481.48                     3676.0
# 2                  56087.55                     2355.0
# 3                      0.00                      230.0
# 4                  10170.92                      563.0
#
#    Total Amount (Jan-Mar24)  Total Quantity (Apr-Jun24)  \
# 0                  80345.87                      3516.0
# 1                  34995.52                      1291.0
# 2                  39299.70                      4864.0
# ...

# %%
data.columns
# Out:
# Index(['Item Name', 'Category', 'Total Quantity(Oct-Dec23)',
#        'Total Amount (Oct-Dec23)', 'Total Quantity(Jan-Mar24)',
#        'Total Amount (Jan-Mar24)', 'Total Quantity (Apr-Jun24)',
#        'Total Amount (Apr-Jun24)', 'Total Quantity (Jul-Sep24)',
#        'Total Amount (Jul-Sep24)', 'Total Quantity (Oct23-Sep24)', 'Revenue'],
#       dtype='object')

# %%
# Step 1: Create a DataFrame from our data
item_dict = {
    "Item Name": [
        "V. Paneer Prantha", "Special Thali", "Water Bottle", "V. Poori Cholle",
        "Veg Fried Rice", "Staff Normal Thali", "Chole Khasta", "Biscuits",
        "Visitor Tea", "Chai", "Chole Bhature", "Tea", "Normal Thali", "Juice",
        "Chole Puri", "Disposale Glass", "Aloo Parantha", "Veg Sandwich",
        "Veg Chowmein", "Dal Rice", "Paneer Parantha", "Spl. Thali", "Dall Roti",
        "Cheese Burger", "Coffee", "V. Paneer Pakora", "Kulhad Dahi",
        "Cheese Sandwich", "Staff Thali", "Payaz Pakora", "Veg Maggie",
        "V. Cholle Bhature", "V. Aloo Prantha", "Gulaab Jamun", "Kadhai Paneer",
        "Donut Cake", "Roti", "Sabji Roti", "Pyaj Pakori", "Half Mater Paneer",
        "Kulhad Lassi", "Chole Chawal", "Cold Drinks@40", "Chilli Manchurian",
        "Dal Prantha", "Paneer Maggie", "Cold Drinks Can", "V. Normal Thali",
        "Paneer Fried Rice", "Rice Haff", "Lays@15", "Paneer Do Pyaza", "Lays @25",
        "Jeera Aloo", "Matar Paneer", "Cholle Rice", "Plain Parantha",
        "Paneer Pakoda", "Rice", "V. Dal Roti", "Veg Poha", "Chilli Paneer",
        "Namkeen", "Bread Ommellete", "Cold Coffee", "Dal Tadka",
        "Extra Sabji Staff", "Without Suger Tea", "Staff Extra Sabji",
        "Ice Cream @30", "Ice Cream @ 25", "Macroni", "Veg Soup", "Half Dall",
        "Chips @5", "Plain Maggie", "Veg Manchurian", "Ice Cream @40",
        "Braed Butter", "Cold Drink@20", "Chilli Potato", "Burger",
        "Student Milk", "Biscuits @5", "Honey Chilli Potato", "Paneer Burger",
        "Kadhai Aloo", "Lays @10", "Samosa", "French Fried", "Hand Made Namkeen",
        "Staff Gulab Jamun", "Masala Aloo", "hot milk", "Maaza", "Chole Samosa",
        "V.sabzi Roti", "V.coffee", "Energy Drink"
    ]
}

df = pd.DataFrame(item_dict)

# Step 2: Define the categorization logic
categories = {
    "Meals": [
        "V. Paneer Prantha", "Special Thali", "Staff Normal Thali", "Normal Thali",
        "Chole Bhature", "Dal Rice", "Paneer Parantha", "Spl. Thali", "Sabji Roti",
        "Half Mater Paneer", "Paneer Do Pyaza", "Jeera Aloo", "Matar Paneer",
        "Cholle Rice", "V. Dal Roti", "Veg Fried Rice", "Paneer Fried Rice",
        "Kadhai Paneer", "Rice Haff", "Dal Tadka", "Extra Sabji Staff",
        "Staff Extra Sabji", "V. Poori Cholle", "Chole Puri", "Dall Roti",
        "V. Normal Thali", "Kadhai Aloo", "Chilli Paneer"
    ],
    "Snacks": [
        "Aloo Parantha", "Veg Sandwich", "Veg Chowmein", "Cheese Burger",
        "V. Paneer Pakora", "Cheese Sandwich", "Pyaj Pakori", "Veg Maggie",
        "Paneer Maggie", "Macroni", "Veg Soup", "Plain Maggie", "Veg Manchurian",
        "Chilli Manchurian", "Honey Chilli Potato", "Chilli Potato", "French Fried",
        "Samosa", "Chole Samosa", "Burger", "Paneer Burger"
    ],
    "Beverages": [
        "Water Bottle", "Visitor Tea", "Chai", "Tea", "Juice", "Coffee",
        "Kulhad Lassi", "Cold Drinks@40", "Cold Drinks Can", "Without Suger Tea",
        "Cold Drink@20", "Energy Drink", "Student Milk", "V.coffee", "hot milk"
    ],
    "Desserts": [
        "Gulaab Jamun", "Donut Cake", "Ice Cream @30", "Ice Cream @25", "Ice Cream @40",
        "Staff Gulab Jamun"
    ],
    "Miscellaneous": [
        "Biscuits", "Disposale Glass", "Kulhad Dahi", "Lays@15", "Lays @25",
        "Chips @5", "Lays @10", "Bread Butter", "Namkeen", "Hand Made Namkeen",
        "Bread Ommellete", "Maaza"
    ]
}

def categorize_item(item_name):
    for category, items in categories.items():
        if item_name in items:
            return category
    return "Uncategorized"

# Step 3: Add a new column for categories
data["Category"] = df["Item Name"].apply(categorize_item)

# %%
data.head()
# Out:
#            Item Name   Category  Total Quantity(Oct-Dec23)  \
# 0  V. Paneer Prantha      Meals                        0.0
# 1      Special Thali      Meals                     2777.0
# 2       Water Bottle  Beverages                     3309.0
# 3    V. Poori Cholle      Meals                        0.0
# 4     Veg Fried Rice      Meals                      178.0
#
#    Total Amount (Oct-Dec23)  Total Quantity(Jan-Mar24)  \
# 0                      0.00                      703.0
# 1                 264481.48                     3676.0
# 2                  56087.55                     2355.0
# 3                      0.00                      230.0
# 4                  10170.92                      563.0
#
#    Total Amount (Jan-Mar24)  Total Quantity (Apr-Jun24)  \
# 0                  80345.87                      3516.0
# 1                  34995.52                      1291.0
# 2                  39299.70                      4864.0
# ...

# %%
data[data['Category']=='Uncategorized']
# Out:
#             Item Name       Category  Total Quantity(Oct-Dec23)  \
# 6        Chole Khasta  Uncategorized                        0.0
# 28        Staff Thali  Uncategorized                      516.0
# 29       Payaz Pakora  Uncategorized                        0.0
# 31  V. Cholle Bhature  Uncategorized                        0.0
# 32    V. Aloo Prantha  Uncategorized                        0.0
# 36               Roti  Uncategorized                     1901.0
# 41       Chole Chawal  Uncategorized                       72.0
# 44        Dal Prantha  Uncategorized                        0.0
# 56     Plain Parantha  Uncategorized                       16.0
# 57      Paneer Pakoda  Uncategorized                       53.0
# 58               Rice  Uncategorized                       36.0
# 60           Veg Poha  Uncategorized                       10.0
# 64        Cold Coffee  Uncategorized                        0.0
# 70     Ice Cream @ 25  Uncategorized                       37.0
# ...

# %%
data.to_excel("categorized_items.xlsx", index=False)

# %%
cat_data=pd.read_excel('categorized_items.xlsx')
cat_data.head()
# Out:
#            Item Name   Category  Total Quantity(Oct-Dec23)  \
# 0  V. Paneer Prantha      Meals                        0.0
# 1      Special Thali      Meals                     2777.0
# 2       Water Bottle  Beverages                     3309.0
# 3    V. Poori Cholle      Meals                        0.0
# 4     Veg Fried Rice      Meals                      178.0
#
#    Total Amount (Oct-Dec23)  Total Quantity(Jan-Mar24)  \
# 0                      0.00                      703.0
# 1                 264481.48                     3676.0
# 2                  56087.55                     2355.0
# 3                      0.00                      230.0
# 4                  10170.92                      563.0
#
#    Total Amount (Jan-Mar24)  Total Quantity (Apr-Jun24)  \
# 0                  80345.87                      3516.0
# 1                  34995.52                      1291.0
# 2                  39299.70                      4864.0
# ...
